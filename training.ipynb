# %%
from ultralytics import YOLO
import os

# %%
import torch
print(f"CUDA ishlayaptimi?: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Sizning daxshatli kartangiz: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA ishlayaptimi?: True
# Sizning daxshatli kartangiz: NVIDIA GeForce RTX 5070

# %%
def train_model():
    model = YOLO('yolov8s.pt') 
    
    model.train(
        data=r'D:\tyreDetetction\Dataset\Tyre_error_proofing.v15i.yolov9\data.yaml',
        epochs=100,
        imgsz=640,
        batch=16,
        device=0,
        project='TyreDetection_Project',
        name='exp_v1_yolov8s',
        exist_ok=True
    )

# Ishga tushirish
train_model()
# Out:
# New https://pypi.org/project/ultralytics/8.4.40 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37  Python-3.12.0 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...
